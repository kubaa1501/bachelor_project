# %%
import pandas as pd
import numpy as np
import os

# ---------------------------
# Paths
# ---------------------------
final_data_path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data"

users_file = os.path.join(final_data_path, "users.csv")
friends_file = os.path.join(final_data_path, "friends.csv")  # not used yet
user_games_file = os.path.join(final_data_path, "user_games.csv")
games_file = os.path.join(final_data_path, "games.csv")

# ---------------------------
# Load data
# ---------------------------
users = pd.read_csv(users_file)
user_games = pd.read_csv(user_games_file)
games = pd.read_csv(games_file)

# ---------------------------
# Convert account_created → datetime
# (assuming Unix timestamp seconds)
# ---------------------------
users["account_created"] = pd.to_datetime(users["account_created"], unit="s", errors="coerce")

now = pd.Timestamp.now()

users["account_age_minutes"] = (
    (now - users["account_created"]).dt.total_seconds() / 60
)

users["account_age_years"] = (
    (now - users["account_created"]).dt.days / 365.25
)

# ---------------------------
# Cap playtime by account age
# ---------------------------
user_games = user_games.merge(
    users[["steamid", "account_age_minutes"]],
    on="steamid",
    how="left"
)

user_games["playtime_minutes_capped"] = np.minimum(
    user_games["playtime_minutes"],
    user_games["account_age_minutes"]
)

# ---------------------------
# USER FEATURES
# ---------------------------

# Total owned games
user_total_games = (
    user_games.groupby("steamid")["appid"]
    .nunique()
    .rename("total_games_owned")
)

# Total playtime
user_total_playtime = (
    user_games.groupby("steamid")["playtime_minutes_capped"]
    .sum()
    .rename("total_playtime_minutes")
)

# median playtime
user_median_playtime = (
    user_games.groupby("steamid")["playtime_minutes_capped"]
    .median()
    .rename("median_playtime_minutes")
)

# Unique genres played
user_games_genres = user_games.merge(
    games[["appid", "genres"]],
    on="appid",
    how="left"
)

user_games_genres["genres"] = user_games_genres["genres"].fillna("")
user_games_genres["genres"] = user_games_genres["genres"].str.split(";")

user_genres = (
    user_games_genres.explode("genres")
    .groupby("steamid")["genres"]
    .nunique()
    .rename("unique_genres_played")
)

# Combine all user features
user_features = (
    users.set_index("steamid")[["account_age_years", "country"]]
    .join([
        user_total_games,
        user_total_playtime,
        median_playtime_minutes,
        user_genres
    ])
    .reset_index()
)

# ---------------------------
# GAME FEATURES
# ---------------------------

# Total playtime per game (capped)
game_total_playtime = (
    user_games.groupby("appid")["playtime_minutes_capped"]
    .sum()
    .rename("total_playtime_minutes")
)

# Release year
games["release_date"] = pd.to_datetime(
    games["release_date"], errors="coerce"
)
games["release_year"] = games["release_date"].dt.year

game_features = (
    games.set_index("appid")
    .join(game_total_playtime)
    .reset_index()
)

# ---------------------------
# Save outputs
# ---------------------------
user_features_file = os.path.join(final_data_path, "user_features.csv")
game_features_file = os.path.join(final_data_path, "game_features.csv")

user_features.to_csv(user_features_file, index=False)
game_features.to_csv(game_features_file, index=False)

print("✅ Feature engineering complete")
print("User features saved to:", user_features_file)
print("Game features saved to:", game_features_file)
# Out:
# ✅ Feature engineering complete
# User features saved to: C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data\user_features.csv
# Game features saved to: C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data\game_features.csv

# %%
final_data_path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\features"

user_features_file = os.path.join(final_data_path, "users_features.csv")
game_features_file = os.path.join(final_data_path, "games_features.csv")

user_features = pd.read_csv(user_features_file)
game_features = pd.read_csv(game_features_file)
print(user_features.head())
print(game_features.head())
print(user_features.describe())
print(game_features.describe())
# Out:
#              steamid  account_age_years country  total_games_owned  \
# 0  76561198064675174          13.711157      IT                170
# 1  76561198109425210          12.377823      BE                104
# 2  76561198281198045          10.042437     NaN                 70
# 3  76561197994839969          18.184805      BE                889
# 4  76561197972380369          21.147159      IT                479
#
#    total_playtime_minutes  avg_playtime_minutes  unique_genres_played
# 0                505414.0           2973.023529                    15
# 1                358581.0           3447.894231                    23
# 2                254987.0           3642.671429                    13
# 3                110264.0            124.031496                    31
# 4                156707.0            327.154489                    23
#      appid                         name  \
# 0      730             Counter-Strike 2
# 1      550                Left 4 Dead 2
# 2   218620                     PAYDAY 2
# 3   431960             Wallpaper Engine
# 4  3240220  Grand Theft Auto V Enhanced
#
#                                               genres  \
# 0                                Action;Free To Play
# 1                                             Action
# 2                                         Action;RPG
# 3  Casual;Indie;Animation & Modeling;Design & Ill...
# 4                            Action;Adventure;Racing
#
#                          developer                 publisher      platforms  \
# 0                            Valve                     Valve  windows;linux
# 1                            Valve                     Valve  windows;linux
# 2  OVERKILL - a Starbreeze Studio.  Starbreeze Entertainment  windows;linux
# 3            Wallpaper Engine Team     Wallpaper Engine Team        windows
# 4                   Rockstar North            Rockstar Games        windows
#
#   release_date  user_count  release_year  total_playtime_minutes
# 0   2012-08-21       38752        2012.0            2.210033e+09
# 1   2009-11-16       26253        2009.0            6.912905e+07
# 2   2013-08-13       24022        2013.0            5.286719e+07
# 3   2018-11-16       21856        2018.0            1.028171e+08
# 4   2025-03-04       19712        2025.0            6.975767e+06
#             steamid  account_age_years  total_games_owned  \
# count  3.102100e+04       31021.000000       31021.000000
# mean   7.656120e+16          10.008683         129.282615
# std    4.492334e+08           3.922607         411.499023
# min    7.656120e+16           0.079398           1.000000
# 25%    7.656120e+16           7.479808          16.000000
# 50%    7.656120e+16           9.976728          45.000000
# 75%    7.656120e+16          12.219028         113.000000
# max    7.656120e+16          22.439425       18381.000000
#
#        total_playtime_minutes  avg_playtime_minutes  unique_genres_played
# count            3.102100e+04          3.102100e+04          31021.000000
# mean             2.714664e+05          9.197244e+03             14.810999
# std              7.385525e+05          2.904835e+04              6.794494
# min              0.000000e+00          0.000000e+00              1.000000
# 25%              5.829900e+04          1.113095e+03             11.000000
# 50%              1.738590e+05          3.198333e+03             15.000000
# 75%              3.473380e+05          7.840523e+03             19.000000
# max              5.685654e+07          2.062614e+06             56.000000
#               appid    user_count  release_year  total_playtime_minutes
# count  2.091800e+04  20918.000000  20679.000000            2.091800e+04
# mean   1.222896e+06    277.405345   2019.202331            4.025796e+05
# std    9.511969e+05   1032.729043      3.982172            1.618429e+07
# min    1.000000e+01      1.000000   1997.000000            0.000000e+00
# 25%    5.021225e+05     11.000000   2017.000000            1.990000e+02
# 50%    8.394350e+05     40.000000   2019.000000            1.347000e+03
# 75%    1.783908e+06    159.000000   2023.000000            1.758925e+04
# max    4.351050e+06  38752.000000   2030.000000            2.210033e+09

# %%
import pandas as pd
import os

# Paths
path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data"
input_file = os.path.join(path, "features/baseline_data.csv")
output_file = os.path.join(path, "features/baseline_data_cleaned.csv")

# Load master dataset
df = pd.read_csv(input_file)

# -------------------------
# RENAME COLUMNS FOR CLARITY
# -------------------------
df = df.rename(columns={
    "total_playtime_minutes_x": "user_total_playtime_minutes",
    "total_playtime_minutes_y": "game_total_playtime_minutes"
})

# -------------------------
# CAP PLAYTIME BASED ON ACCOUNT AGE
# -------------------------
# Maximum possible playtime in minutes based on account age
df['max_playtime_minutes'] = df['account_age_years'] * 365.25 * 24 * 60

# Cap individual playtime
df['playtime_minutes'] = df[['playtime_minutes', 'max_playtime_minutes']].min(axis=1)

# Cap user total playtime
df['user_total_playtime_minutes'] = df[['user_total_playtime_minutes', 'max_playtime_minutes']].min(axis=1)

# Cap game total playtime
df['game_total_playtime_minutes'] = df[['game_total_playtime_minutes', 'max_playtime_minutes']].min(axis=1)

# Drop helper column
df.drop(columns='max_playtime_minutes', inplace=True)

# -------------------------
# ENCODE CATEGORICALS
# -------------------------
df['country'] = df['country'].fillna('NaN')
for col in ['genres', 'developer', 'publisher', 'platforms']:
    df[col] = df[col].fillna('NaN')
# -------------------------
# CHECKS
# -------------------------
print("Columns after cleaning:")
print(df.columns)
print("\nFirst 5 rows:")
print(df.head())
print("\nNumber of rows:", len(df))

# -------------------------
# SAVE CLEANED DATASET
# -------------------------
df.to_csv(output_file, index=False)
print(f"\n✅ Cleaned dataset saved to: {output_file}")
# Out:
# Columns after cleaning:
# Index(['steamid', 'appid', 'playtime_minutes', 'owns_game',
#        'account_age_years', 'country', 'total_games_owned',
#        'user_total_playtime_minutes', 'avg_playtime_minutes',
#        'unique_genres_played', 'name', 'genres', 'developer', 'publisher',
#        'platforms', 'release_date', 'user_count', 'release_year',
#        'game_total_playtime_minutes'],
#       dtype='object')
#
# First 5 rows:
#              steamid  appid  playtime_minutes  owns_game  account_age_years  \
# 0  76561198064675174    400             367.0          1          13.711157
# 1  76561198064675174    500             117.0          1          13.711157
# 2  76561198064675174    550               0.0          1          13.711157
# 3  76561198064675174    620             710.0          1          13.711157
# 4  76561198064675174   3900            7075.0          1          13.711157
#
#   country  total_games_owned  user_total_playtime_minutes  \
# 0      IT                170                     505414.0
# 1      IT                170                     505414.0
# 2      IT                170                     505414.0
# 3      IT                170                     505414.0
# 4      IT                170                     505414.0
#
#    avg_playtime_minutes  unique_genres_played                          name  \
# 0           2973.023529                    15                        Portal
# 1           2973.023529                    15                   Left 4 Dead
# 2           2973.023529                    15                 Left 4 Dead 2
# 3           2973.023529                    15                      Portal 2
# 4           2973.023529                    15  Sid Meier's Civilization® IV
#
#              genres      developer publisher      platforms release_date  \
# 0            Action          Valve     Valve  windows;linux   2007-10-10
# 1            Action          Valve     Valve        windows   2008-11-17
# 2            Action          Valve     Valve  windows;linux   2009-11-16
# 3  Action;Adventure          Valve     Valve  windows;linux   2011-04-18
# 4          Strategy  Firaxis Games        2K    windows;mac   2006-10-25
#
#    user_count  release_year  game_total_playtime_minutes
# 0       12230        2007.0                    2626344.0
# 1        9389        2008.0                    7100773.0
# 2       26253        2009.0                    7211520.0
# 3       17020        2011.0                    7211520.0
# 4        1262        2006.0                     223960.0
#
# Number of rows: 3491801
#
# ✅ Cleaned dataset saved to: C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\features/baseline_data_cleaned.csv

# %%
import pandas as pd
import numpy as np
import os

# ---------------------------
# Paths
# ---------------------------
final_data_path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data"

users_file = os.path.join(final_data_path, "users.csv")
user_games_file = os.path.join(final_data_path, "user_games.csv")
games_file = os.path.join(final_data_path, "games.csv")

baseline_output = os.path.join(final_data_path, "baseline_dataset.csv")

# ---------------------------
# Load data
# ---------------------------
users = pd.read_csv(users_file)
user_games = pd.read_csv(user_games_file)
games = pd.read_csv(games_file)

original_rows = len(user_games)

# ---------------------------
# Account age features
# ---------------------------
users["account_created"] = pd.to_datetime(
    users["account_created"], unit="s", errors="coerce"
)

now = pd.Timestamp.now()

users["account_age_minutes"] = (
    (now - users["account_created"]).dt.total_seconds() / 60
)

users["account_age_years"] = (
    (now - users["account_created"]).dt.days / 365.25
)

# ---------------------------
# Merge account age into interactions
# ---------------------------
user_games = user_games.merge(
    users[["steamid", "account_age_minutes", "account_age_years", "country"]],
    on="steamid",
    how="left"
)

# ---------------------------
# Cap individual playtime
# ---------------------------
user_games["playtime_minutes_capped"] = np.minimum(
    user_games["playtime_minutes"],
    user_games["account_age_minutes"]
)

# ---------------------------
# USER AGGREGATE FEATURES
# ---------------------------
user_agg = user_games.groupby("steamid").agg(
    total_games_owned=("appid", "nunique"),
    total_playtime_minutes=("playtime_minutes_capped", "sum"),
    avg_playtime_minutes=("playtime_minutes_capped", "mean")
)

# Cap lifetime playtime by account age
user_agg = user_agg.join(
    users.set_index("steamid")["account_age_minutes"]
)

user_agg["total_playtime_minutes"] = np.minimum(
    user_agg["total_playtime_minutes"],
    user_agg["account_age_minutes"]
)

user_agg.drop(columns="account_age_minutes", inplace=True)

# ---------------------------
# UNIQUE GENRES PER USER
# ---------------------------
user_games_genres = user_games.merge(
    games[["appid", "genres"]],
    on="appid",
    how="left"
)

user_games_genres["genres"] = (
    user_games_genres["genres"]
    .fillna("")
    .str.split(";")
)

user_genres = (
    user_games_genres.explode("genres")
    .groupby("steamid")["genres"]
    .nunique()
    .rename("unique_genres_played")
)

user_agg = user_agg.join(user_genres)

# ---------------------------
# GAME FEATURES
# ---------------------------
games["release_date"] = pd.to_datetime(
    games["release_date"], errors="coerce"
)
games["release_year"] = games["release_date"].dt.year

game_agg = user_games.groupby("appid")["playtime_minutes_capped"] \
    .sum().rename("game_total_playtime_minutes")

games = games.set_index("appid").join(game_agg).reset_index()

# ---------------------------
# BUILD FINAL BASELINE DATASET
# ---------------------------
baseline = user_games.merge(
    user_agg.reset_index(),
    on="steamid",
    how="left"
)

baseline = baseline.merge(
    games,
    on="appid",
    how="left"
)

# ---------------------------
# Final check: rows preserved
# ---------------------------
print("Original rows:", original_rows)
print("Baseline rows:", len(baseline))

# ---------------------------
# Save baseline dataset
# ---------------------------
baseline.to_csv(baseline_output, index=False)

print("✅ Baseline dataset saved to:", baseline_output)
# Out:
# Original rows: 4010476
# Baseline rows: 4010476
# ✅ Baseline dataset saved to: C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data\baseline_dataset.csv

# %%
print("\n===== BASELINE HEAD =====")
print(baseline.head())

print("\n===== BASELINE INFO =====")
print(baseline.info())

print("\n===== BASELINE DESCRIBE =====")
print(baseline.describe(include="all"))
# Out:
# ===== BASELINE HEAD =====
#              steamid  appid  playtime_minutes  account_age_minutes  \
# 0  76561198064675174    400               367         7.213372e+06
# 1  76561198064675174    500               117         7.213372e+06
# 2  76561198064675174    550                 0         7.213372e+06
# 3  76561198064675174    620               710         7.213372e+06
# 4  76561198064675174   3900              7075         7.213372e+06
#
#    account_age_years country  playtime_minutes_capped  total_games_owned  \
# 0          13.713895      IT                    367.0                170
# 1          13.713895      IT                    117.0                170
# 2          13.713895      IT                      0.0                170
# 3          13.713895      IT                    710.0                170
# 4          13.713895      IT                   7075.0                170
#
#    total_playtime_minutes  avg_playtime_minutes  unique_genres_played  \
# 0                505414.0           2973.023529                    15
# 1                505414.0           2973.023529                    15
# 2                505414.0           2973.023529                    15
# 3                505414.0           2973.023529                    15
# 4                505414.0           2973.023529                    15
#
#                            name            genres      developer publisher  \
# 0                        Portal            Action          Valve     Valve
# 1                   Left 4 Dead            Action          Valve     Valve
# 2                 Left 4 Dead 2            Action          Valve     Valve
# 3                      Portal 2  Action;Adventure          Valve     Valve
# 4  Sid Meier's Civilization® IV          Strategy  Firaxis Games        2K
#
#        platforms release_date  user_count  release_year  \
# 0  windows;linux   2007-10-10       12230        2007.0
# 1        windows   2008-11-17        9389        2008.0
# 2  windows;linux   2009-11-16       26253        2009.0
# 3  windows;linux   2011-04-18       17020        2011.0
# 4    windows;mac   2006-10-25        1262        2006.0
#
#    game_total_playtime_minutes
# 0                    2626344.0
# 1                    7100773.0
# 2                   69129046.0
# 3                   12584145.0
# 4                     223960.0
#
# ===== BASELINE INFO =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4010476 entries, 0 to 4010475
# Data columns (total 20 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   steamid                      int64
#  1   appid                        int64
#  2   playtime_minutes             int64
#  3   account_age_minutes          float64
#  4   account_age_years            float64
#  5   country                      object
#  6   playtime_minutes_capped      float64
#  7   total_games_owned            int64
#  8   total_playtime_minutes       float64
#  9   avg_playtime_minutes         float64
#  10  unique_genres_played         int64
#  11  name                         object
#  12  genres                       object
#  13  developer                    object
#  14  publisher                    object
#  15  platforms                    object
#  16  release_date                 datetime64[ns]
#  17  user_count                   int64
#  18  release_year                 float64
#  19  game_total_playtime_minutes  float64
# dtypes: datetime64[ns](1), float64(7), int64(6), object(6)
# memory usage: 612.0+ MB
# None
#
# ===== BASELINE DESCRIBE =====
#              steamid         appid  playtime_minutes  account_age_minutes  \
# count   4.010476e+06  4.010476e+06      4.010476e+06         4.010476e+06
# unique           NaN           NaN               NaN                  NaN
# top              NaN           NaN               NaN                  NaN
# freq             NaN           NaN               NaN                  NaN
# mean    7.656120e+16  6.208985e+05      2.099791e+03         6.538785e+06
# min     7.656120e+16  1.000000e+01      0.000000e+00         4.252061e+04
# 25%     7.656120e+16  2.352100e+05      0.000000e+00         5.179461e+06
# 50%     7.656120e+16  4.069700e+05      2.400000e+01         6.390366e+06
# 75%     7.656120e+16  7.928000e+05      3.120000e+02         7.763371e+06
# max     7.656120e+16  4.351050e+06      5.339119e+06         1.180303e+07
# std     3.441600e+08  6.481128e+05      2.162820e+04         2.188821e+06
#
#         account_age_years  country  playtime_minutes_capped  \
# count        4.010476e+06  3020018             4.010476e+06
# unique                NaN      242                      NaN
# top                   NaN       CN                      NaN
# freq                  NaN   592385                      NaN
# mean         1.243080e+01      NaN             2.099791e+03
# min          7.939767e-02      NaN             0.000000e+00
# 25%          9.845311e+00      NaN             0.000000e+00
# 50%          1.214784e+01      NaN             2.400000e+01
# 75%          1.475975e+01      NaN             3.120000e+02
# max          2.243943e+01      NaN             5.339119e+06
# std          4.161636e+00      NaN             2.162820e+04
#
#         total_games_owned  total_playtime_minutes  avg_playtime_minutes  \
# count        4.010476e+06            4.010476e+06          4.010476e+06
# unique                NaN                     NaN                   NaN
# top                   NaN                     NaN                   NaN
# freq                  NaN                     NaN                   NaN
# mean         1.439018e+03            5.247943e+05          2.099791e+03
# min          1.000000e+00            0.000000e+00          0.000000e+00
# 25%          1.340000e+02            1.818940e+05          2.292977e+02
# 50%          3.820000e+02            3.751800e+05          7.825167e+02
# 75%          1.326000e+03            6.609840e+05          2.252958e+03
# max          1.838100e+04            1.174431e+07          2.062614e+06
# std          2.762102e+03            6.644118e+05          6.203216e+03
#
#         unique_genres_played              name   genres developer publisher  \
# count           4.010476e+06           4010469  3989333   3989158   3963792
# unique                   NaN             20870     1161     13906     10624
# top                      NaN  Counter-Strike 2   Action     Valve     Valve
# freq                     NaN             24647   537225    184911    204895
# mean            2.607461e+01               NaN      NaN       NaN       NaN
# min             1.000000e+00               NaN      NaN       NaN       NaN
# 25%             1.800000e+01               NaN      NaN       NaN       NaN
# 50%             2.400000e+01               NaN      NaN       NaN       NaN
# 75%             3.300000e+01               NaN      NaN       NaN       NaN
# max             5.600000e+01               NaN      NaN       NaN       NaN
# std             1.075497e+01               NaN      NaN       NaN       NaN
#
#        platforms                   release_date    user_count  release_year  \
# count    4010476                        3910308  4.010476e+06  3.910308e+06
# unique         5                            NaN           NaN           NaN
# top      windows                            NaN           NaN           NaN
# freq     2383619                            NaN           NaN           NaN
# mean         NaN  2016-07-27 01:40:54.748833024  3.886173e+03  2.016050e+03
# min          NaN            1997-11-14 00:00:00  1.000000e+00  1.997000e+03
# 25%          NaN            2014-01-22 00:00:00  4.590000e+02  2.014000e+03
# 50%          NaN            2016-09-26 00:00:00  1.720000e+03  2.016000e+03
# 75%          NaN            2019-08-27 00:00:00  5.056000e+03  2.019000e+03
# max          NaN            2030-09-24 00:00:00  3.875200e+04  2.030000e+03
# std          NaN                            NaN  5.550732e+03  4.727256e+00
#
#         game_total_playtime_minutes
# count                  4.010476e+06
# unique                          NaN
# top                             NaN
# freq                            NaN
# mean                   2.216232e+07
# min                    0.000000e+00
# 25%                    4.531400e+04
# 50%                    3.363660e+05
# 75%                    3.025599e+06
# max                    2.210033e+09
# std                    1.751243e+08

# %%
import pandas as pd
import numpy as np
import os

# ---------------------------
# Paths
# ---------------------------
final_data_path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data"

users_file = os.path.join(final_data_path, "users.csv")
user_games_file = os.path.join(final_data_path, "user_games.csv")
games_file = os.path.join(final_data_path, "games.csv")

baseline_output = os.path.join(final_data_path, "baseline_dataset.csv")

# ---------------------------
# Load data
# ---------------------------
users = pd.read_csv(users_file)
user_games = pd.read_csv(user_games_file)
games = pd.read_csv(games_file)

original_rows = len(user_games)

# ---------------------------
# Account age features
# ---------------------------
users["account_created"] = pd.to_datetime(
    users["account_created"], unit="s", errors="coerce"
)

now = pd.Timestamp.now()

users["account_age_minutes"] = (
    (now - users["account_created"]).dt.total_seconds() / 60
)

# Keep country for baseline
# ---------------------------
# Merge account age into interactions
# ---------------------------
user_games = user_games.merge(
    users[["steamid", "account_age_minutes", "country"]],
    on="steamid",
    how="left"
)

# ---------------------------
# Cap individual playtime
# ---------------------------
user_games["playtime_minutes_capped"] = np.minimum(
    user_games["playtime_minutes"],
    user_games["account_age_minutes"]
)

# ---------------------------
# USER AGGREGATE FEATURES
# ---------------------------
user_agg = user_games.groupby("steamid").agg(
    total_games_owned=("appid", "nunique"),
    total_playtime_minutes=("playtime_minutes_capped", "sum"),
    median_playtime_minutes=("playtime_minutes_capped", "median")
)

# Cap lifetime total_playtime by account age
user_agg = user_agg.join(users.set_index("steamid")["account_age_minutes"])
user_agg["total_playtime_minutes"] = np.minimum(
    user_agg["total_playtime_minutes"],
    user_agg["account_age_minutes"]
)
user_agg.drop(columns="account_age_minutes", inplace=True)

# ---------------------------
# UNIQUE GENRES PER USER
# ---------------------------
user_games_genres = user_games.merge(
    games[["appid", "genres"]],
    on="appid",
    how="left"
)

user_games_genres["genres"] = (
    user_games_genres["genres"]
    .fillna("")
    .str.split(";")
)

user_genres = (
    user_games_genres.explode("genres")
    .groupby("steamid")["genres"]
    .nunique()
    .rename("unique_genres_played")
)

user_agg = user_agg.join(user_genres)

# ---------------------------
# GAME FEATURES
# ---------------------------
games["release_date"] = pd.to_datetime(
    games["release_date"], errors="coerce"
)

game_agg = user_games.groupby("appid")["playtime_minutes_capped"] \
    .sum().rename("game_total_playtime_minutes")

games = games.set_index("appid").join(game_agg).reset_index()

# ---------------------------
# BUILD FINAL BASELINE DATASET
# ---------------------------
baseline = user_games.merge(
    user_agg.reset_index(),
    on="steamid",
    how="left"
)

baseline = baseline.merge(
    games,
    on="appid",
    how="left"
)

# ---------------------------
# DROP REDUNDANT COLUMNS
# ---------------------------
baseline = baseline.drop(columns=[
    "playtime_minutes",
    "account_age_minutes",
    "release_year",
    "playtime_minutes_capped"
], errors="ignore")

# ---------------------------
# Final checks
# ---------------------------
print("Original rows:", original_rows)
print("Baseline rows:", len(baseline))

print("\n===== BASELINE HEAD =====")
print(baseline.head())

print("\n===== BASELINE DESCRIBE =====")
print(baseline.describe(include="all"))

# ---------------------------
# Save baseline dataset
# ---------------------------
baseline.to_csv(baseline_output, index=False)
print("✅ Baseline dataset saved to:", baseline_output)
# Out:
# Original rows: 4010476
# Baseline rows: 4010476
#
# ===== BASELINE HEAD =====
#              steamid  appid country  total_games_owned  \
# 0  76561198064675174    400      IT                170
# 1  76561198064675174    500      IT                170
# 2  76561198064675174    550      IT                170
# 3  76561198064675174    620      IT                170
# 4  76561198064675174   3900      IT                170
#
#    total_playtime_minutes  median_playtime_minutes  unique_genres_played  \
# 0                505414.0                    588.0                    15
# 1                505414.0                    588.0                    15
# 2                505414.0                    588.0                    15
# 3                505414.0                    588.0                    15
# 4                505414.0                    588.0                    15
#
#                            name            genres      developer publisher  \
# 0                        Portal            Action          Valve     Valve
# 1                   Left 4 Dead            Action          Valve     Valve
# 2                 Left 4 Dead 2            Action          Valve     Valve
# 3                      Portal 2  Action;Adventure          Valve     Valve
# 4  Sid Meier's Civilization® IV          Strategy  Firaxis Games        2K
#
#        platforms release_date  user_count  game_total_playtime_minutes
# 0  windows;linux   2007-10-10       12230                    2626344.0
# 1        windows   2008-11-17        9389                    7100773.0
# 2  windows;linux   2009-11-16       26253                   69129046.0
# 3  windows;linux   2011-04-18       17020                   12584145.0
# 4    windows;mac   2006-10-25        1262                     223960.0
#
# ===== BASELINE DESCRIBE =====
#              steamid         appid  country  total_games_owned  \
# count   4.010476e+06  4.010476e+06  3020018       4.010476e+06
# unique           NaN           NaN      242                NaN
# top              NaN           NaN       CN                NaN
# freq             NaN           NaN   592385                NaN
# mean    7.656120e+16  6.208985e+05      NaN       1.439018e+03
# min     7.656120e+16  1.000000e+01      NaN       1.000000e+00
# 25%     7.656120e+16  2.352100e+05      NaN       1.340000e+02
# 50%     7.656120e+16  4.069700e+05      NaN       3.820000e+02
# 75%     7.656120e+16  7.928000e+05      NaN       1.326000e+03
# max     7.656120e+16  4.351050e+06      NaN       1.838100e+04
# std     3.441600e+08  6.481128e+05      NaN       2.762102e+03
#
#         total_playtime_minutes  median_playtime_minutes  unique_genres_played  \
# count             4.010476e+06             4.010476e+06          4.010476e+06
# unique                     NaN                      NaN                   NaN
# top                        NaN                      NaN                   NaN
# freq                       NaN                      NaN                   NaN
# mean              5.247945e+05             1.926524e+02          2.607461e+01
# min               0.000000e+00             0.000000e+00          1.000000e+00
# 25%               1.818940e+05             0.000000e+00          1.800000e+01
# 50%               3.751800e+05             7.200000e+01          2.400000e+01
# 75%               6.609840e+05             1.920000e+02          3.300000e+01
# max               1.174434e+07             2.062614e+06          5.600000e+01
# std               6.644131e+05             3.099936e+03          1.075497e+01
#
#                     name   genres developer publisher platforms  \
# count            4010469  3989333   3989158   3963792   4010476
# unique             20870     1161     13906     10624         5
# top     Counter-Strike 2   Action     Valve     Valve   windows
# freq               24647   537225    184911    204895   2383619
# mean                 NaN      NaN       NaN       NaN       NaN
# min                  NaN      NaN       NaN       NaN       NaN
# 25%                  NaN      NaN       NaN       NaN       NaN
# 50%                  NaN      NaN       NaN       NaN       NaN
# 75%                  NaN      NaN       NaN       NaN       NaN
# max                  NaN      NaN       NaN       NaN       NaN
# std                  NaN      NaN       NaN       NaN       NaN
#
#                          release_date    user_count  \
# count                         3910308  4.010476e+06
# unique                            NaN           NaN
# top                               NaN           NaN
# freq                              NaN           NaN
# mean    2016-07-27 01:40:54.748833024  3.886173e+03
# min               1997-11-14 00:00:00  1.000000e+00
# 25%               2014-01-22 00:00:00  4.590000e+02
# 50%               2016-09-26 00:00:00  1.720000e+03
# 75%               2019-08-27 00:00:00  5.056000e+03
# max               2030-09-24 00:00:00  3.875200e+04
# std                               NaN  5.550732e+03
#
#         game_total_playtime_minutes
# count                  4.010476e+06
# unique                          NaN
# top                             NaN
# freq                            NaN
# mean                   2.216232e+07
# min                    0.000000e+00
# 25%                    4.531400e+04
# 50%                    3.363660e+05
# 75%                    3.025599e+06
# max                    2.210033e+09
# std                    1.751243e+08
# ✅ Baseline dataset saved to: C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data\baseline_dataset.csv
