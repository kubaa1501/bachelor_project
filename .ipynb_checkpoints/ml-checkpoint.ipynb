# %% [markdown]
# # CREATING FILES

# %% [markdown]
# ## Creating baseline_dataset file

# %%
import pandas as pd
import numpy as np
import os

# ---------------------------
# Paths
# ---------------------------
final_data_path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data"

users_file = os.path.join(final_data_path, "users.csv")
user_games_file = os.path.join(final_data_path, "user_games.csv")
games_file = os.path.join(final_data_path, "games.csv")

baseline_output = os.path.join(final_data_path, "baseline_dataset.csv")

# ---------------------------
# Load data
# ---------------------------
users = pd.read_csv(users_file)
user_games = pd.read_csv(user_games_file)
games = pd.read_csv(games_file)

original_rows = len(user_games)

# ---------------------------
# Account age features
# ---------------------------
users["account_created"] = pd.to_datetime(
    users["account_created"], unit="s", errors="coerce"
)

now = pd.Timestamp.now()

users["account_age_minutes"] = (
    (now - users["account_created"]).dt.total_seconds() / 60
)

# Keep country for baseline
# ---------------------------
# Merge account age into interactions
# ---------------------------
user_games = user_games.merge(
    users[["steamid", "account_age_minutes", "country"]],
    on="steamid",
    how="left"
)

# ---------------------------
# Cap individual playtime
# ---------------------------
user_games["playtime_minutes_capped"] = np.minimum(
    user_games["playtime_minutes"],
    user_games["account_age_minutes"]
)

# ---------------------------
# USER AGGREGATE FEATURES
# ---------------------------
user_agg = user_games.groupby("steamid").agg(
    total_games_owned=("appid", "nunique"),
    total_playtime_minutes=("playtime_minutes_capped", "sum"),
    median_playtime_minutes=("playtime_minutes_capped", "median")
)

# Cap lifetime total_playtime by account age
user_agg = user_agg.join(users.set_index("steamid")["account_age_minutes"])
user_agg["total_playtime_minutes"] = np.minimum(
    user_agg["total_playtime_minutes"],
    user_agg["account_age_minutes"]
)
user_agg.drop(columns="account_age_minutes", inplace=True)

# ---------------------------
# UNIQUE GENRES PER USER
# ---------------------------
user_games_genres = user_games.merge(
    games[["appid", "genres"]],
    on="appid",
    how="left"
)

user_games_genres["genres"] = (
    user_games_genres["genres"]
    .fillna("")
    .str.split(";")
)

user_genres = (
    user_games_genres.explode("genres")
    .groupby("steamid")["genres"]
    .nunique()
    .rename("unique_genres_played")
)

user_agg = user_agg.join(user_genres)

# ---------------------------
# GAME FEATURES
# ---------------------------
games["release_date"] = pd.to_datetime(
    games["release_date"], errors="coerce"
)

game_agg = user_games.groupby("appid")["playtime_minutes_capped"] \
    .sum().rename("game_total_playtime_minutes")

games = games.set_index("appid").join(game_agg).reset_index()

# ---------------------------
# BUILD FINAL BASELINE DATASET
# ---------------------------
baseline = user_games.merge(
    user_agg.reset_index(),
    on="steamid",
    how="left"
)

baseline = baseline.merge(
    games,
    on="appid",
    how="left"
)

# ---------------------------
# DROP REDUNDANT COLUMNS
# ---------------------------
baseline = baseline.drop(columns=[
    "playtime_minutes",
    "account_age_minutes",
    "release_year",
    "playtime_minutes_capped"
], errors="ignore")

# ---------------------------
# Final checks
# ---------------------------
print("Original rows:", original_rows)
print("Baseline rows:", len(baseline))

print("\n===== BASELINE HEAD =====")
print(baseline.head())

print("\n===== BASELINE DESCRIBE =====")
print(baseline.describe(include="all"))

# ---------------------------
# Save baseline dataset
# ---------------------------
baseline.to_csv(baseline_output, index=False)
print("✅ Baseline dataset saved to:", baseline_output)
# Out:
# Original rows: 4010476
# Baseline rows: 4010476
#
# ===== BASELINE HEAD =====
#              steamid  appid country  total_games_owned  \
# 0  76561198064675174    400      IT                170
# 1  76561198064675174    500      IT                170
# 2  76561198064675174    550      IT                170
# 3  76561198064675174    620      IT                170
# 4  76561198064675174   3900      IT                170
#
#    total_playtime_minutes  median_playtime_minutes  unique_genres_played  \
# 0                505414.0                    588.0                    15
# 1                505414.0                    588.0                    15
# 2                505414.0                    588.0                    15
# 3                505414.0                    588.0                    15
# 4                505414.0                    588.0                    15
#
#                            name            genres      developer publisher  \
# 0                        Portal            Action          Valve     Valve
# 1                   Left 4 Dead            Action          Valve     Valve
# 2                 Left 4 Dead 2            Action          Valve     Valve
# 3                      Portal 2  Action;Adventure          Valve     Valve
# 4  Sid Meier's Civilization® IV          Strategy  Firaxis Games        2K
#
#        platforms release_date  user_count  game_total_playtime_minutes
# 0  windows;linux   2007-10-10       12230                    2626344.0
# 1        windows   2008-11-17        9389                    7100773.0
# 2  windows;linux   2009-11-16       26253                   69129046.0
# 3  windows;linux   2011-04-18       17020                   12584145.0
# 4    windows;mac   2006-10-25        1262                     223960.0
#
# ===== BASELINE DESCRIBE =====
#              steamid         appid  country  total_games_owned  \
# count   4.010476e+06  4.010476e+06  3020018       4.010476e+06
# unique           NaN           NaN      242                NaN
# top              NaN           NaN       CN                NaN
# freq             NaN           NaN   592385                NaN
# mean    7.656120e+16  6.208985e+05      NaN       1.439018e+03
# min     7.656120e+16  1.000000e+01      NaN       1.000000e+00
# 25%     7.656120e+16  2.352100e+05      NaN       1.340000e+02
# 50%     7.656120e+16  4.069700e+05      NaN       3.820000e+02
# 75%     7.656120e+16  7.928000e+05      NaN       1.326000e+03
# max     7.656120e+16  4.351050e+06      NaN       1.838100e+04
# std     3.441600e+08  6.481128e+05      NaN       2.762102e+03
#
#         total_playtime_minutes  median_playtime_minutes  unique_genres_played  \
# count             4.010476e+06             4.010476e+06          4.010476e+06
# unique                     NaN                      NaN                   NaN
# top                        NaN                      NaN                   NaN
# freq                       NaN                      NaN                   NaN
# mean              5.247945e+05             1.926524e+02          2.607461e+01
# min               0.000000e+00             0.000000e+00          1.000000e+00
# 25%               1.818940e+05             0.000000e+00          1.800000e+01
# 50%               3.751800e+05             7.200000e+01          2.400000e+01
# 75%               6.609840e+05             1.920000e+02          3.300000e+01
# max               1.174434e+07             2.062614e+06          5.600000e+01
# std               6.644131e+05             3.099936e+03          1.075497e+01
#
#                     name   genres developer publisher platforms  \
# count            4010469  3989333   3989158   3963792   4010476
# unique             20870     1161     13906     10624         5
# top     Counter-Strike 2   Action     Valve     Valve   windows
# freq               24647   537225    184911    204895   2383619
# mean                 NaN      NaN       NaN       NaN       NaN
# min                  NaN      NaN       NaN       NaN       NaN
# 25%                  NaN      NaN       NaN       NaN       NaN
# 50%                  NaN      NaN       NaN       NaN       NaN
# 75%                  NaN      NaN       NaN       NaN       NaN
# max                  NaN      NaN       NaN       NaN       NaN
# std                  NaN      NaN       NaN       NaN       NaN
#
#                          release_date    user_count  \
# count                         3910308  4.010476e+06
# unique                            NaN           NaN
# top                               NaN           NaN
# freq                              NaN           NaN
# mean    2016-07-27 01:40:54.748833024  3.886173e+03
# min               1997-11-14 00:00:00  1.000000e+00
# 25%               2014-01-22 00:00:00  4.590000e+02
# 50%               2016-09-26 00:00:00  1.720000e+03
# 75%               2019-08-27 00:00:00  5.056000e+03
# max               2030-09-24 00:00:00  3.875200e+04
# std                               NaN  5.550732e+03
#
#         game_total_playtime_minutes
# count                  4.010476e+06
# unique                          NaN
# top                             NaN
# freq                            NaN
# mean                   2.216232e+07
# min                    0.000000e+00
# 25%                    4.531400e+04
# 50%                    3.363660e+05
# 75%                    3.025599e+06
# max                    2.210033e+09
# std                    1.751243e+08
# ✅ Baseline dataset saved to: C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\final_data\baseline_dataset.csv

# %%
import pandas as pd

baseline_path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\baseline\baseline_dataset.csv"

baseline = pd.read_csv(baseline_path)

print("Loaded:", baseline.shape)
# Out:
# Loaded: (4010476, 15)

# %%
numeric_cols = [
    "total_games_owned",
    "total_playtime_minutes",
    "median_playtime_minutes",
    "unique_genres_played",
    "user_count",
    "game_total_playtime_minutes"
]

corr = baseline[numeric_cols].corr()

print(corr.round(2))
# Out:
#                              total_games_owned  total_playtime_minutes  \
# total_games_owned                         1.00                    0.38
# total_playtime_minutes                    0.38                    1.00
# median_playtime_minutes                  -0.02                    0.04
# unique_genres_played                      0.75                    0.36
# user_count                               -0.25                   -0.13
# game_total_playtime_minutes              -0.06                   -0.04
#
#                              median_playtime_minutes  unique_genres_played  \
# total_games_owned                              -0.02                  0.75
# total_playtime_minutes                          0.04                  0.36
# median_playtime_minutes                         1.00                 -0.05
# unique_genres_played                           -0.05                  1.00
# user_count                                      0.06                 -0.36
# game_total_playtime_minutes                     0.08                 -0.11
#
#                              user_count  game_total_playtime_minutes
# total_games_owned                 -0.25                        -0.06
# total_playtime_minutes            -0.13                        -0.04
# median_playtime_minutes            0.06                         0.08
# unique_genres_played              -0.36                        -0.11
# user_count                         1.00                         0.57
# game_total_playtime_minutes        0.57                         1.00

# %% [markdown]
# ## Creating baseline_small file

# %%
import pandas as pd
import numpy as np

SEED = 42
np.random.seed(SEED)

baseline_path = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\baseline\baseline_dataset.csv"

df = pd.read_csv(baseline_path)

# ------------------
# SAMPLE USERS
# ------------------
n_users = 1000

sampled_users = np.random.choice(
    df["steamid"].unique(),
    size=n_users,
    replace=False
)

df_small = df[df["steamid"].isin(sampled_users)]

print("Users:", df_small["steamid"].nunique())
print("Rows:", len(df_small))

df_small.to_csv("baseline_small.csv", index=False)
# Out:
# Users: 1000
# Rows: 133207

# %% [markdown]
# ## Creating network_feat_dataset file

# %% [markdown]
# ### Standarization and PCA on games-similarity matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# ======================================
# SETTINGS
# ======================================

FILE_PATH = r"D:\bachelor_project\micheles_algorithm\new_version\game_game_dists_sq_20988.mmap"

TEST_SIZE = 500                # Try 500 first (can increase to 1000)
USE_LOG = True
VARIANCE_THRESHOLD = 0.90
MAX_COMPONENTS = 200           # Safety cap for PCA

# ======================================
# 1️⃣ LOAD UPPER TRIANGLE MATRIX
# ======================================

print("Loading matrix...")
matrix = np.memmap(FILE_PATH, dtype=np.float32, mode='r', shape=(20988, 20988))

print("Matrix shape:", matrix.shape)
print("First 5x5 block:\n", matrix[:5, :5])

# ======================================
# 2️⃣ CREATE SMALL SAMPLE
# ======================================

print(f"\nRunning TEST MODE with size {TEST_SIZE} x {TEST_SIZE}")
upper_small = matrix[:TEST_SIZE, :TEST_SIZE]

print("Small matrix shape:", upper_small.shape)

# ======================================
# 3️⃣ RECONSTRUCT SYMMETRIC MATRIX
# ======================================

print("\nReconstructing symmetric matrix...")
S = upper_small + upper_small.T

# Remove doubled diagonal
np.fill_diagonal(S, 0)

print("Symmetric matrix created.")

# ======================================
# 4️⃣ SANITY CHECKS (BEFORE NORMALIZATION)
# ======================================

print("\nSanity checks (before normalization):")
print("Any NaNs?", np.isnan(S).sum())
print("Min value:", np.min(S))
print("Max value:", np.max(S))
print("Matrix symmetric check:", np.allclose(S, S.T))

# ======================================
# 5️⃣ OPTIONAL LOG NORMALIZATION
# ======================================

if USE_LOG:
    print("\nApplying log1p normalization...")
    S = np.log1p(S)

    print("After log normalization:")
    print("Min value:", np.min(S))
    print("Max value:", np.max(S))

# ======================================
# 6️⃣ STANDARDIZE FOR PCA
# ======================================

print("\nStandardizing features...")
scaler = StandardScaler()
S_scaled = scaler.fit_transform(S)

print("Scaled matrix mean (should be ~0):", np.mean(S_scaled))
print("Scaled matrix std (should be ~1):", np.std(S_scaled))

# ======================================
# 7️⃣ PCA
# ======================================

print("\nFitting PCA...")

pca = PCA(
    n_components=min(MAX_COMPONENTS, TEST_SIZE),
    svd_solver='randomized',
    random_state=42
)

S_reduced_full = pca.fit_transform(S_scaled)

explained = pca.explained_variance_ratio_
cumulative = np.cumsum(explained)

# ======================================
# 8️⃣ AUTOMATIC COMPONENT SELECTION
# ======================================

optimal_components = np.argmax(cumulative >= VARIANCE_THRESHOLD) + 1

print(f"\nVariance threshold: {VARIANCE_THRESHOLD}")
print(f"Optimal number of components: {optimal_components}")
print(f"Achieved variance: {cumulative[optimal_components - 1]:.4f}")

game_embeddings = S_reduced_full[:, :optimal_components]

print("Final embedding shape:", game_embeddings.shape)

# ======================================
# 9️⃣ SANITY CHECKS AFTER PCA
# ======================================

print("\nSanity checks (after PCA):")
print("Any NaNs?", np.isnan(game_embeddings).sum())
print("Embedding mean (should be ~0):", np.mean(game_embeddings))
print("Embedding std:", np.std(game_embeddings))

# ======================================
# 🔟 SCREE PLOT
# ======================================

plt.figure(figsize=(8,5))
plt.plot(cumulative)
plt.axhline(y=VARIANCE_THRESHOLD, linestyle='--')
plt.axvline(x=optimal_components, linestyle='--')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Explained Variance (Small Test)")
plt.show()

# ======================================
# 11️⃣ SAVE SMALL TEST EMBEDDINGS
# ======================================

embedding_df = pd.DataFrame(
    game_embeddings,
    columns=[f"game_emb_{i}" for i in range(optimal_components)]
)

embedding_df["game_index"] = embedding_df.index

embedding_df.to_csv("game_pca_embeddings_small_test.csv", index=False)

print("\nEmbeddings saved to game_pca_embeddings_small_test.csv")
# Out:
# Loading matrix...
# Matrix shape: (20988, 20988)
# First 5x5 block:
#  [[   0.      3044.4028  2602.1     2589.407   3096.4314 ]
#  [   0.         0.       868.38324  842.5616   203.53499]
#  [   0.         0.         0.        69.28137  983.63904]
#  [   0.         0.         0.         0.       952.70447]
#  [   0.         0.         0.         0.         0.     ]]
#
# Running TEST MODE with size 500 x 500
# Small matrix shape: (500, 500)
#
# Reconstructing symmetric matrix...
# Symmetric matrix created.
#
# Sanity checks (before normalization):
# Any NaNs? 0
# Min value: 0.0
# Max value: 7152.5093
# Matrix symmetric check: True
#
# Applying log1p normalization...
# After log normalization:
# Min value: 0.0
# Max value: 8.875359
#
# Standardizing features...
# Scaled matrix mean (should be ~0): -5.126953e-09
# Scaled matrix std (should be ~1): 1.0
#
# Fitting PCA...
#
# Variance threshold: 0.9
# Optimal number of components: 50
# Achieved variance: 0.9003
# Final embedding shape: (500, 50)
#
# Sanity checks (after PCA):
# Any NaNs? 0
# Embedding mean (should be ~0): -1.0604858e-08
# Embedding std: 3.000458
# Embeddings saved to game_pca_embeddings_small_test.csv

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# ## Naive classifier

# %% [markdown]
# ## ML for baseline

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm  # <-- progress bar

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, confusion_matrix
)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# -----------------------
# SETTINGS
# -----------------------
SEED = 42
np.random.seed(SEED)

file = r"C:\Users\jkgas\OneDrive\Desktop\data_science\Spring_2026\bachelor_project\data\baseline\baseline_small.csv"

# -----------------------
# LOAD DATA
# -----------------------
df = pd.read_csv(file, sep=",", quotechar='"')

print(f"Original shape: {df.shape}")
print(f"Unique users: {df['steamid'].nunique()}")
print(f"Unique games: {df['appid'].nunique()}")

# -----------------------
# SEPARATE USER & GAME FEATURES
# -----------------------
users_features = df[['steamid', 'country', 'total_games_owned',
                     'total_playtime_minutes', 'median_playtime_minutes',
                     'unique_genres_played', 'user_count']].drop_duplicates('steamid')

games_features = df[['appid', 'name', 'genres', 'developer',
                     'publisher', 'platforms', 'release_date',
                     'game_total_playtime_minutes']].drop_duplicates('appid')

# -----------------------
# POSITIVE SAMPLES
# -----------------------
positives = df[['steamid', 'appid']].copy()
positives['owned'] = 1

# -----------------------
# NEGATIVE SAMPLING WITH PROGRESS BAR
# -----------------------
all_games = set(df['appid'].unique())
neg_samples = []

print("Generating negative samples...")
for user in tqdm(users_features['steamid'], desc="Users"):
    owned_games = set(positives[positives['steamid'] == user]['appid'])
    not_owned = list(all_games - owned_games)
    
    if len(not_owned) == 0:
        continue
    
    n_sample = len(owned_games)
    sampled = np.random.choice(not_owned, size=n_sample, replace=len(not_owned) < n_sample)
    
    neg_samples.extend([(user, game) for game in sampled])

negatives = pd.DataFrame(neg_samples, columns=['steamid', 'appid'])
negatives['owned'] = 0

# -----------------------
# COMBINE POSITIVES + NEGATIVES
# -----------------------
all_samples = pd.concat([positives, negatives], ignore_index=True)
print(f"After negative sampling: {all_samples.shape}")

# -----------------------
# MERGE FEATURES
# -----------------------
all_samples = all_samples.merge(users_features, on='steamid', how='left')
all_samples = all_samples.merge(games_features, on='appid', how='left')

# -----------------------
# CHECK MISSING VALUES
# -----------------------
print("Missing values per column:")
print(all_samples.isna().sum())

# -----------------------
# SELECT FEATURES
# -----------------------
target = 'owned'

numeric_features = [
    'total_games_owned', 'total_playtime_minutes', 'median_playtime_minutes',
    'unique_genres_played', 'user_count', 'game_total_playtime_minutes'
]

categorical_features = [
    'country', 'developer', 'publisher', 'platforms', 'genres'
]

X = all_samples[numeric_features + categorical_features]
y = all_samples[target]

# -----------------------
# PREPROCESSING PIPELINE
# -----------------------
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# -----------------------
# DEFINE MODELS
# -----------------------
models = {
    "LogisticRegression": LogisticRegression(max_iter=500, random_state=SEED),
    "RandomForest": RandomForestClassifier(n_estimators=1, random_state=SEED),
    "XGBoost": XGBClassifier(eval_metric='logloss', use_label_encoder=False, random_state=SEED)
}

# -----------------------
# TRAIN / TEST SPLIT
# -----------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=SEED
)

# -----------------------
# TRAIN + EVALUATE WITH PROGRESS BAR
# -----------------------
for name, model in tqdm(models.items(), desc="Training models"):
    print(f"\n==== {name} ====")
    
    pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('model', model)
    ])
    
    pipe.fit(X_train, y_train)
    
    y_pred = pipe.predict(X_test)
    y_proba = pipe.predict_proba(X_test)[:, 1]
    
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1 Score:", f1_score(y_test, y_pred))
    print("ROC AUC:", roc_auc_score(y_test, y_proba))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Original shape: (133207, 15)
# Unique users: 1000
# Unique games: 18832
# Generating negative samples...
# Users: 100%|██████████████████████████████████████████████████████████████████████| 1000/1000 [00:07<00:00, 126.32it/s]
# After negative sampling: (266414, 3)
# Missing values per column:
# steamid                            0
# appid                              0
# owned                              0
# country                        61918
# total_games_owned                  0
# total_playtime_minutes             0
# median_playtime_minutes            0
# unique_genres_played               0
# user_count                         0
# name                               6
# genres                          1235
# developer                       1071
# publisher                       2917
# platforms                          0
# release_date                    4738
# game_total_playtime_minutes        0
# dtype: int64
# Training models:   0%|                                                                           | 0/3 [00:00<?, ?it/s]
# ==== LogisticRegression ====
# Training models:  33%|██████████████████████▎                                            | 1/3 [00:16<00:32, 16.21s/it]
# Accuracy: 0.8370962595949928
# Precision: 0.8467776190292312
# Recall: 0.8231297623963064
# F1 Score: 0.8347862499524153
# ROC AUC: 0.9068943108267193
# Confusion Matrix:
#  [[22674  3968]
#  [ 4712 21929]]
#
# ==== RandomForest ====
# Accuracy: 0.8273745847643714
# Precision: 0.8312507121425045
# Recall: 0.8215157088697872
# F1 Score: 0.8263545403058334
# ROC AUC: 0.8273300505287123
# Training models:  67%|████████████████████████████████████████████▋                      | 2/3 [00:51<00:27, 27.34s/it]
# Confusion Matrix:
#  [[22199  4443]
#  [ 4755 21886]]
#
# ==== XGBoost ====
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:34:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.8518476812491789
# Precision: 0.8535168772392985
# Recall: 0.8494801246199467
# F1 Score: 0.8514937166077207
# Training models: 100%|███████████████████████████████████████████████████████████████████| 3/3 [01:00<00:00, 20.16s/it]
# ROC AUC: 0.9236982163626914
# Confusion Matrix:
#  [[22758  3884]
#  [ 4010 22631]]

# %%
from sklearn.model_selection import learning_curve, StratifiedKFold, cross_val_score

# -----------------------
# CROSS-VALIDATION
# -----------------------
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

for name, model in tqdm(models.items(), desc="CV + Learning Curves"):
    print(f"\n==== {name} ====")
    
    pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('model', model)
    ])
    
    # -----------------------
    # CROSS-VALIDATION METRICS
    # -----------------------
    accuracy = cross_val_score(pipe, X, y, cv=cv, scoring='accuracy')
    f1 = cross_val_score(pipe, X, y, cv=cv, scoring='f1')
    roc_auc = cross_val_score(pipe, X, y, cv=cv, scoring='roc_auc')
    
    print("CV Accuracy:", np.round(accuracy.mean(), 4), "±", np.round(accuracy.std(), 4))
    print("CV F1:", np.round(f1.mean(), 4), "±", np.round(f1.std(), 4))
    print("CV ROC AUC:", np.round(roc_auc.mean(), 4), "±", np.round(roc_auc.std(), 4))
    
    # -----------------------
    # LEARNING CURVES
    # -----------------------
    train_sizes, train_scores, val_scores = learning_curve(
        pipe, X, y,
        cv=cv,
        scoring='f1',
        train_sizes=np.linspace(0.1, 1.0, 5),
        n_jobs=-1
    )
    
    train_mean = np.mean(train_scores, axis=1)
    val_mean = np.mean(val_scores, axis=1)
    
    print("Learning curve (F1) – train vs val:")
    for ts, tr, val in zip(train_sizes, train_mean, val_mean):
        print(f"  {ts} samples: train F1={tr:.4f}, val F1={val:.4f}")
# Out:
# CV + Learning Curves:   0%|                                                                      | 0/3 [00:00<?, ?it/s]
# ==== LogisticRegression ====
# CV Accuracy: 0.8376 ± 0.0017
# CV F1: 0.8356 ± 0.0016
# CV ROC AUC: 0.9071 ± 0.0012
# C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 10 fits failed out of a total of 25.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1301, in fit
#     raise ValueError(
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# CV + Learning Curves:  33%|████████████████████▎                                        | 1/3 [04:43<09:26, 283.40s/it]
# Learning curve (F1) – train vs val:
#   21313 samples: train F1=nan, val F1=nan
#   69267 samples: train F1=nan, val F1=nan
#   117222 samples: train F1=0.9948, val F1=0.6961
#   165176 samples: train F1=0.9070, val F1=0.8107
#   213131 samples: train F1=0.8610, val F1=0.8356
#
# ==== RandomForest ====
# CV Accuracy: 0.8335 ± 0.0056
# CV F1: 0.8329 ± 0.0056
# CV ROC AUC: 0.8335 ± 0.0056
# CV + Learning Curves:  67%|████████████████████████████████████████▋                    | 2/3 [14:07<07:28, 448.44s/it]
# Learning curve (F1) – train vs val:
#   21313 samples: train F1=1.0000, val F1=0.6667
#   69267 samples: train F1=1.0000, val F1=0.6667
#   117222 samples: train F1=0.9981, val F1=0.7034
#   165176 samples: train F1=0.9621, val F1=0.7973
#   213131 samples: train F1=0.9381, val F1=0.8322
#
# ==== XGBoost ====
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:48:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:48:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:48:57] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:34] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:49:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:50:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:50:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:50:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:50:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# CV Accuracy: 0.8544 ± 0.0014
# CV F1: 0.8538 ± 0.0013
# CV ROC AUC: 0.9254 ± 0.0012
# C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 10 fits failed out of a total of 25.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\core.py", line 751, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "C:\Users\jkgas\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 1761, in fit
#     raise ValueError(
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0], got [1]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# CV + Learning Curves: 100%|█████████████████████████████████████████████████████████████| 3/3 [17:14<00:00, 344.72s/it]
# Learning curve (F1) – train vs val:
#   21313 samples: train F1=nan, val F1=nan
#   69267 samples: train F1=nan, val F1=nan
#   117222 samples: train F1=0.9868, val F1=0.6901
#   165176 samples: train F1=0.9070, val F1=0.8250
#   213131 samples: train F1=0.8584, val F1=0.8538

# %% [markdown]
# ## ML for model with network features

# %% [markdown]
# ## NN ML for baseline

# %% [markdown]
# ## NN ML for model with network features
